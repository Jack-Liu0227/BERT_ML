# %%
import pandas as pd
df=pd.read_csv("USTB_steel_processed.csv")
df.insert(0,"ID",range(1,len(df)+1))
df.to_csv("USTB_steel_processed_withID.csv",index=False)

# df=pd.read_csv("KQ_processed.csv")
# df.insert(0,"ID",range(1,len(df)+1))
# df.to_csv("KQ_processed_withID.csv",index=False)
