# %%
# import pandas as pd
# csv_path="HTC_processed.csv"
# df=pd.read_csv(csv_path)
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Columns: 161 entries, compositions to Unnamed: 160
# dtypes: float64(150), int64(9), object(2)
# memory usage: 42.9+ KB

# %%
import pandas as pd
df=pd.read_csv("Pitting potential data_xiongjie_processed.csv")
df.insert(0,"ID",range(1,len(df)+1))
df.to_csv("Pitting potential data_xiongjie_processed.csv",index=False)

df=pd.read_csv("Strength and ductility data_xiongjie_processed.csv")
df.insert(0,"ID",range(1,len(df)+1))
df.to_csv("Strength and ductility data_xiongjie_processed.csv",index=False)
