# %%
import pandas as pd
df=pd.read_csv("RoomTemperature_HEA_train.csv")
df.insert(0,"ID",range(1,len(df)+1))
df.to_csv("RoomTemperature_HEA_train_with_ID.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_145196\1398995459.py in ?()
#       1 import pandas as pd
#       2 df=pd.read_csv("RoomTemperature_HEA_train.csv")
# ----> 3 df.insert(0,"ID",range(1,len(df)+1))
#       4 df.to_csv("RoomTemperature_HEA_train_with_ID.csv",index=False)
#       5
#
# c:\Users\HK\miniconda3\envs\llm\lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5161                 "'self.flags.allows_duplicate_labels' is False."
#    5162             )
#    5163         if not allow_duplicates and column in self.columns:
#    5164             # Should this be a different kind of error??
# -> 5165             raise ValueError(f"cannot insert {column}, already exists")
#    5166         if not is_integer(loc):
#    5167             raise TypeError("loc must be int")
# ...
